# %%
''' Dense Net '''
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn as nn
import torch.nn.functional as F
import math

class Bottleneck(nn.Module):
    def __init__(self, nChannels, growthRate):
        super(Bottleneck, self).__init__()
        interChannels = 4*growthRate
        self.bn1 = nn.BatchNorm2d(nChannels)
        self.conv1 = nn.Conv2d(nChannels, interChannels, kernel_size=1,
                               bias=False)
        self.bn2 = nn.BatchNorm2d(interChannels)
        self.conv2 = nn.Conv2d(interChannels, growthRate, kernel_size=3,
                               padding=1, bias=False)

    def forward(self, x):
        out = self.conv1(F.relu(self.bn1(x)))
        out = self.conv2(F.relu(self.bn2(out)))
        out = torch.cat((x, out), 1)
        return out

class SingleLayer(nn.Module):
    def __init__(self, nChannels, growthRate):
        super(SingleLayer, self).__init__()
        self.bn1 = nn.BatchNorm2d(nChannels)
        self.conv1 = nn.Conv2d(nChannels, growthRate, kernel_size=3,
                               padding=1, bias=False)

    def forward(self, x):
        out = self.conv1(F.relu(self.bn1(x)))
        out = torch.cat((x, out), 1)
        return out

class Transition(nn.Module):
    def __init__(self, nChannels, nOutChannels):
        super(Transition, self).__init__()
        self.bn1 = nn.BatchNorm2d(nChannels)
        self.conv1 = nn.Conv2d(nChannels, nOutChannels, kernel_size=1,
                               bias=False)

    def forward(self, x):
        out = self.conv1(F.relu(self.bn1(x)))
        out = F.avg_pool2d(out, 2)
        return out


class DenseNet(nn.Module):
    def __init__(self, growthRate, depth, reduction, nClasses, bottleneck):
        super(DenseNet, self).__init__()

        nDenseBlocks = (depth-4) // 3
        if bottleneck:
            nDenseBlocks //= 2

        nChannels = 2*growthRate
        self.conv1 = nn.Conv2d(3, nChannels, kernel_size=3, padding=1,
                               bias=False)
        self.dense1 = self._make_dense(nChannels, growthRate, nDenseBlocks, bottleneck)
        nChannels += nDenseBlocks*growthRate
        nOutChannels = int(math.floor(nChannels*reduction))
        self.trans1 = Transition(nChannels, nOutChannels)

        nChannels = nOutChannels
        self.dense2 = self._make_dense(nChannels, growthRate, nDenseBlocks, bottleneck)
        nChannels += nDenseBlocks*growthRate
        nOutChannels = int(math.floor(nChannels*reduction))
        self.trans2 = Transition(nChannels, nOutChannels)

        nChannels = nOutChannels
        self.dense3 = self._make_dense(nChannels, growthRate, nDenseBlocks, bottleneck)
        nChannels += nDenseBlocks*growthRate

        self.bn1 = nn.BatchNorm2d(nChannels)
        self.fc = nn.Linear(nChannels+1, nClasses)

        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                n = m.kernel_size[0] * m.kernel_size[1] * m.out_channels
                m.weight.data.normal_(0, math.sqrt(2. / n))
            elif isinstance(m, nn.BatchNorm2d):
                m.weight.data.fill_(1)
                m.bias.data.zero_()
            elif isinstance(m, nn.Linear):
                m.bias.data.zero_()

    def _make_dense(self, nChannels, growthRate, nDenseBlocks, bottleneck):
        layers = []
        for i in range(int(nDenseBlocks)):
            if bottleneck:
                layers.append(Bottleneck(nChannels, growthRate))
            else:
                layers.append(SingleLayer(nChannels, growthRate))
            nChannels += growthRate
        return nn.Sequential(*layers)

    def forward(self, x):
        out = self.conv1(x)
        out = self.trans1(self.dense1(out))
        out = self.trans2(self.dense2(out))
        out = self.dense3(out)
        out = torch.squeeze(F.avg_pool2d(F.relu(self.bn1(out)), 8))
        out = F.log_softmax(self.fc(out))
        return out

# %%
# Model Test
model = DenseNet(growthRate=12, depth=100, reduction=0.5,
                            bottleneck=False, nClasses=10)
print(model)
# Out:
# DenseNet(
#   (conv1): Conv2d(3, 24, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#   (dense1): Sequential(
#     (0): SingleLayer(
#       (bn1): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(24, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (1): SingleLayer(
#       (bn1): BatchNorm2d(36, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(36, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (2): SingleLayer(
#       (bn1): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(48, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (3): SingleLayer(
#       (bn1): BatchNorm2d(60, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(60, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (4): SingleLayer(
#       (bn1): BatchNorm2d(72, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(72, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (5): SingleLayer(
#       (bn1): BatchNorm2d(84, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(84, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (6): SingleLayer(
#       (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(96, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (7): SingleLayer(
#       (bn1): BatchNorm2d(108, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(108, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (8): SingleLayer(
#       (bn1): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(120, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (9): SingleLayer(
#       (bn1): BatchNorm2d(132, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(132, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (10): SingleLayer(
#       (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(144, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (11): SingleLayer(
#       (bn1): BatchNorm2d(156, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(156, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (12): SingleLayer(
#       (bn1): BatchNorm2d(168, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(168, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (13): SingleLayer(
#       (bn1): BatchNorm2d(180, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(180, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (14): SingleLayer(
#       (bn1): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(192, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (15): SingleLayer(
#       (bn1): BatchNorm2d(204, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(204, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (16): SingleLayer(
#       (bn1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(216, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (17): SingleLayer(
#       (bn1): BatchNorm2d(228, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(228, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (18): SingleLayer(
#       (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(240, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (19): SingleLayer(
#       (bn1): BatchNorm2d(252, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(252, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (20): SingleLayer(
#       (bn1): BatchNorm2d(264, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(264, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (21): SingleLayer(
#       (bn1): BatchNorm2d(276, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(276, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (22): SingleLayer(
#       (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(288, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (23): SingleLayer(
#       (bn1): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(300, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (24): SingleLayer(
#       (bn1): BatchNorm2d(312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(312, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (25): SingleLayer(
#       (bn1): BatchNorm2d(324, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(324, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (26): SingleLayer(
#       (bn1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(336, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (27): SingleLayer(
#       (bn1): BatchNorm2d(348, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(348, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (28): SingleLayer(
#       (bn1): BatchNorm2d(360, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(360, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (29): SingleLayer(
#       (bn1): BatchNorm2d(372, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(372, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (30): SingleLayer(
#       (bn1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(384, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (31): SingleLayer(
#       (bn1): BatchNorm2d(396, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(396, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#   )
#   (trans1): Transition(
#     (bn1): BatchNorm2d(408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv1): Conv2d(408, 204, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (dense2): Sequential(
#     (0): SingleLayer(
#       (bn1): BatchNorm2d(204, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(204, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (1): SingleLayer(
#       (bn1): BatchNorm2d(216, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(216, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (2): SingleLayer(
#       (bn1): BatchNorm2d(228, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(228, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (3): SingleLayer(
#       (bn1): BatchNorm2d(240, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(240, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (4): SingleLayer(
#       (bn1): BatchNorm2d(252, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(252, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (5): SingleLayer(
#       (bn1): BatchNorm2d(264, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(264, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (6): SingleLayer(
#       (bn1): BatchNorm2d(276, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(276, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (7): SingleLayer(
#       (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(288, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (8): SingleLayer(
#       (bn1): BatchNorm2d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(300, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (9): SingleLayer(
#       (bn1): BatchNorm2d(312, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(312, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (10): SingleLayer(
#       (bn1): BatchNorm2d(324, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(324, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (11): SingleLayer(
#       (bn1): BatchNorm2d(336, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(336, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (12): SingleLayer(
#       (bn1): BatchNorm2d(348, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(348, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (13): SingleLayer(
#       (bn1): BatchNorm2d(360, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(360, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (14): SingleLayer(
#       (bn1): BatchNorm2d(372, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(372, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (15): SingleLayer(
#       (bn1): BatchNorm2d(384, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(384, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (16): SingleLayer(
#       (bn1): BatchNorm2d(396, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(396, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (17): SingleLayer(
#       (bn1): BatchNorm2d(408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(408, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (18): SingleLayer(
#       (bn1): BatchNorm2d(420, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(420, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (19): SingleLayer(
#       (bn1): BatchNorm2d(432, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(432, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (20): SingleLayer(
#       (bn1): BatchNorm2d(444, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(444, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (21): SingleLayer(
#       (bn1): BatchNorm2d(456, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(456, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (22): SingleLayer(
#       (bn1): BatchNorm2d(468, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(468, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (23): SingleLayer(
#       (bn1): BatchNorm2d(480, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(480, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (24): SingleLayer(
#       (bn1): BatchNorm2d(492, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(492, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (25): SingleLayer(
#       (bn1): BatchNorm2d(504, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(504, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (26): SingleLayer(
#       (bn1): BatchNorm2d(516, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(516, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (27): SingleLayer(
#       (bn1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(528, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (28): SingleLayer(
#       (bn1): BatchNorm2d(540, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(540, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (29): SingleLayer(
#       (bn1): BatchNorm2d(552, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(552, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (30): SingleLayer(
#       (bn1): BatchNorm2d(564, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(564, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (31): SingleLayer(
#       (bn1): BatchNorm2d(576, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(576, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#   )
#   (trans2): Transition(
#     (bn1): BatchNorm2d(588, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (conv1): Conv2d(588, 294, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   )
#   (dense3): Sequential(
#     (0): SingleLayer(
#       (bn1): BatchNorm2d(294, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(294, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (1): SingleLayer(
#       (bn1): BatchNorm2d(306, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(306, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (2): SingleLayer(
#       (bn1): BatchNorm2d(318, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(318, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (3): SingleLayer(
#       (bn1): BatchNorm2d(330, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(330, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (4): SingleLayer(
#       (bn1): BatchNorm2d(342, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(342, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (5): SingleLayer(
#       (bn1): BatchNorm2d(354, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(354, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (6): SingleLayer(
#       (bn1): BatchNorm2d(366, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(366, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (7): SingleLayer(
#       (bn1): BatchNorm2d(378, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(378, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (8): SingleLayer(
#       (bn1): BatchNorm2d(390, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(390, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (9): SingleLayer(
#       (bn1): BatchNorm2d(402, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(402, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (10): SingleLayer(
#       (bn1): BatchNorm2d(414, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(414, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (11): SingleLayer(
#       (bn1): BatchNorm2d(426, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(426, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (12): SingleLayer(
#       (bn1): BatchNorm2d(438, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(438, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (13): SingleLayer(
#       (bn1): BatchNorm2d(450, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(450, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (14): SingleLayer(
#       (bn1): BatchNorm2d(462, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(462, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (15): SingleLayer(
#       (bn1): BatchNorm2d(474, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(474, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (16): SingleLayer(
#       (bn1): BatchNorm2d(486, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(486, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (17): SingleLayer(
#       (bn1): BatchNorm2d(498, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(498, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (18): SingleLayer(
#       (bn1): BatchNorm2d(510, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(510, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (19): SingleLayer(
#       (bn1): BatchNorm2d(522, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(522, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (20): SingleLayer(
#       (bn1): BatchNorm2d(534, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(534, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (21): SingleLayer(
#       (bn1): BatchNorm2d(546, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(546, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (22): SingleLayer(
#       (bn1): BatchNorm2d(558, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(558, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (23): SingleLayer(
#       (bn1): BatchNorm2d(570, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(570, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (24): SingleLayer(
#       (bn1): BatchNorm2d(582, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(582, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (25): SingleLayer(
#       (bn1): BatchNorm2d(594, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(594, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (26): SingleLayer(
#       (bn1): BatchNorm2d(606, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(606, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (27): SingleLayer(
#       (bn1): BatchNorm2d(618, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(618, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (28): SingleLayer(
#       (bn1): BatchNorm2d(630, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(630, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (29): SingleLayer(
#       (bn1): BatchNorm2d(642, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(642, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (30): SingleLayer(
#       (bn1): BatchNorm2d(654, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(654, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#     (31): SingleLayer(
#       (bn1): BatchNorm2d(666, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (conv1): Conv2d(666, 12, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     )
#   )
#   (bn1): BatchNorm2d(678, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc): Linear(in_features=679, out_features=10, bias=True)
# )
